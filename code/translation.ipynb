# %% [markdown]
# Supported languages:
# * https://github.com/facebookresearch/seamless_communication/blob/main/docs/m4t/README.md

# %%
from utils import textInput, audioInput, sample_rate
from IPython.display import Audio
# Out:
# e:\Users\chinm\anaconda3\envs\PyTorch\lib\site-packages\transformers\deepspeed.py:23: FutureWarning: transformers.deepspeed module is deprecated and will be removed in a future version. Please import deepspeed modules directly from transformers.integrations
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %% [markdown]
# <center>Translating English text

# %%
text = "The first of these questions might seem to have an easy answer, namely, that lookism can be justified \
only when appearance is a genuine qualification for work, that is, has a real bearing on a person’s ability \
to do a job or do it well, such as modelling or some acting roles. But this just pushes back the problem. \
We must now ask: when is appearance a genuine qualification for a job? And even: should genuine \
qualifications always count, or can there be moral reasons for not counting them?"

# %%
a, t = textInput(text, "english", "hindi")
t
# Out:
# '"उदाहरण के लिए, ""Lookism"" केवल तब ही उचित हो सकता है जब उपस्थिति काम के लिए एक वास्तविक योग्यता हो, अर्थात्, एक व्यक्ति की नौकरी करने की क्षमता पर एक वास्तविक प्रभाव हो, या इसे अच्छी तरह से करें, जैसे कि मॉडलिंग या कुछ अभिनय भूमिकाएं, लेकिन यह केवल समस्या को पीछे धकेल देता है। अब हमें पूछना चाहिएः जब उपस्थिति एक नौकरी के लिए एक वास्तविक योग्यता है?"'

# %%
Audio(a, rate=sample_rate-1000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <center>Translating Odia audio

# %%
a2, t2 = audioInput("", tgt_lang = "hindi")
t2Audio_files/odia.wav
# Out:
# 'मेरा नाम चिनमे साहु है और मैं टेस्ट कर रहा हूँ कि मेरा मॉडल ओडिया से दूसरी लैंग्वेज को ट्रांसलेट कर पा रहा है कि नहीं।'

# %%
Audio(a2, rate = sample_rate-1000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <center>Translating English Audio

# %%
a3, t3 = audioInput("Audio_files/english.wav", tgt_lang = "hindi")
t3
# Out:
# 'हम संयुक्त राज्य अमेरिका के लोग अधिक पूर्ण संघ बनाने के लिए न्याय स्थापित करें घरेलू शांति सुनिश्चित करें आम रक्षा के लिए प्रावधान करें'

# %%
Audio(a3, rate = sample_rate-1000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <center>Translating Marathi audio

# %%
a4, t4 = audioInput("Audio_files/marathi.wav", tgt_lang = "english")
t4
# Out:
# "My name is Akash, I'm a student, I'm doing a modeling test for a brand."

# %%
Audio(a4, rate = sample_rate-1000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a5, t5 = audioInput("Audio_files/marathi.wav", tgt_lang = "hindi")
t5
# Out:
# 'मेरा नाम आकाश है, मैं एक छात्र हूँ, मैं चिनमयां का मॉडल टेस्ट कर रहा हूँ'

# %%
Audio(a5, rate = sample_rate-1000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <center>Translating Hindi audio

# %%
a6, t6 = audioInput("Audio_files/hindi.wav", tgt_lang = "english")
t6
# Out:
# "I'm fine, but I'm a little hungry, I'll go and eat now"

# %%
Audio(a6, rate = sample_rate-1000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
a7, t7 = audioInput("Audio_files/hindi.wav", tgt_lang = "french")
t7
# Out:
# "Je suis bien, mais j'ai un peu faim, je vais aller manger."

# %%
Audio(a7, rate = sample_rate-1000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ----------------------------------------------------------------------------------------------------
